# %%
#Pandas Lib useful for data processing and analysis

#Pandas Data Frame
#Data Frame is a 2D data structure with labelled axes(rows and columns)

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.6.1

# %%
#importing Pandas Library
import pandas as pd

# %%
from sklearn.datasets import fetch_california_housing
import pandas as pd
# import data from fetch_california_housing into housing_data
housing = fetch_california_housing()
print(type(housing)) #pandas help to display data in a more structured way

calliDf = pd.DataFrame(housing.data, columns=housing.feature_names)

print(calliDf.head()) #display first 5 rows of the data

print(calliDf.shape) #display the shape of the data
# Out:
# <class 'sklearn.utils._bunch.Bunch'>
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25
# (20640, 8)

# %%
#Importing data from a CSV file
customers = pd.read_csv('../dataset/customers.csv') 

customers.head() #display first 5 rows of the data
customers.shape
# Out:
# (50, 21)

# %%
#Exporting data to a CSV file
calliDf.to_csv('../dataset/California Housing Details.csv') #index=False to avoid saving the index column

# %%
#Exporting data to an Excel file
calliDf.to_excel('../dataset/California Housing Details.xlsx')

# %%
#Statistical summary of the data -> .describe()
customers.describe()
#count or number of values in each coulms
customers.count()
# Out:
# CustomerID          50
# Gender              50
# SeniorCitizen       50
# Partner             50
# Dependents          50
# Tenure              50
# PhoneService        50
# MultipleLines       50
# InternetService     50
# OnlineSecurity      50
# OnlineBackup        50
# DeviceProtection    50
# TechSupport         50
# StreamingTV         50
# StreamingMovies     50
# Contract            50
# PaperlessBilling    50
# PaymentMethod       50
# MonthlyCharges      50
# TotalCharges        50
# Churn               50
# dtype: int64

# %%
#Creating Dataframe with randome values

import numpy as np

random_data = pd.DataFrame(np.random.rand(20,5), columns=['A','B','C','D','E'])
random_data.head()
# Out:
#           A         B         C         D         E
# 0  0.328558  0.571858  0.092097  0.316704  0.802012
# 1  0.557559  0.881762  0.764545  0.522939  0.975213
# 2  0.637353  0.850578  0.939239  0.704983  0.505359
# 3  0.055535  0.143875  0.144465  0.508617  0.315604
# 4  0.247405  0.073704  0.218512  0.962883  0.635125

# %%
#Inspecting a Dataframe

#finding no of rows & columns -> .shape
calliDf.shape

#first 5 rows -> .head()
calliDf.head()

#last 5 rows -> .tail()
calliDf.tail()
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 20635    -121.09
# 20636    -121.21
# 20637    -121.22
# 20638    -121.32
# 20639    -121.24

# %%
#certains info about datframe -> .info()
customers.info() #non-null values means no missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   CustomerID        50 non-null     object
#  1   Gender            50 non-null     object
#  2   SeniorCitizen     50 non-null     int64
#  3   Partner           50 non-null     object
#  4   Dependents        50 non-null     object
#  5   Tenure            50 non-null     int64
#  6   PhoneService      50 non-null     object
#  7   MultipleLines     50 non-null     object
#  8   InternetService   50 non-null     object
#  9   OnlineSecurity    50 non-null     object
#  10  OnlineBackup      50 non-null     object
#  11  DeviceProtection  50 non-null     object
#  12  TechSupport       50 non-null     object
#  13  StreamingTV       50 non-null     object
#  14  StreamingMovies   50 non-null     object
#  15  Contract          50 non-null     object
# ...

# %%
#Find no of missing values in each column -> .isnull().sum()
customers.isnull().sum()
# Out:
# CustomerID          0
# Gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# Tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
#count number of specific values in a column based on  label-> .value_counts()
customers.value_counts('Churn')
# Out:
# Churn
# No     38
# Yes    12
# Name: count, dtype: int64

# %%
#How to group data based on label -> .groupby().mean()
calliDf.groupby('HouseAge').mean()
# Out:
#             MedInc  AveRooms  AveBedrms   Population  AveOccup   Latitude  \
# HouseAge
# 1.0       4.003400  9.088091   1.552106   328.500000  3.244088  36.205000
# 2.0       5.167766  7.649087   1.273514  2083.051724  2.747802  35.494483
# 3.0       5.460258  6.851805   1.192486  3001.774194  2.734708  35.284516
# 4.0       5.180673  6.112610   1.116190  2813.162304  2.786138  34.966963
# 5.0       4.697636  5.963211   1.128014  2471.381148  3.279108  35.234262
# 6.0       4.383393  5.832246   1.105839  2165.637500  2.886158  35.233125
# 7.0       4.464457  6.236576   1.145118  2613.080000  2.936948  35.544286
# 8.0       4.459338  6.280481   1.175100  2018.354369  3.360742  35.743835
# 9.0       4.316425  6.014117   1.144547  1886.975610  2.899606  35.683366
# 10.0      4.050508  6.047608   1.195510  1712.924242  2.852738  35.914621
# 11.0      3.932593  6.288396   1.245155  1989.905512  2.932461  35.896063
# ...

# %%
#mean value - column wise
calliDf.mean()
# Out:
# MedInc           3.870671
# HouseAge        28.639486
# AveRooms         5.429000
# AveBedrms        1.096675
# Population    1425.476744
# AveOccup         3.070655
# Latitude        35.631861
# Longitude     -119.569704
# dtype: float64

# %%
#Statistical summary of the data -> .describe()
customers.describe()
# Out:
#        SeniorCitizen    Tenure  MonthlyCharges  TotalCharges
# count      50.000000  50.00000        50.00000     50.000000
# mean        0.500000  24.50000        58.25000   1702.750000
# std         0.505076  14.57738        21.86607   1391.864981
# min         0.000000   0.00000        21.50000      0.000000
# 25%         0.000000  12.25000        39.87500    470.375000
# 50%         0.500000  24.50000        58.25000   1390.750000
# 75%         1.000000  36.75000        76.62500   2761.125000
# max         1.000000  49.00000        95.00000   4581.500000

# %%
#count or number of values in each coulms
customers.count()
# Out:
# CustomerID          50
# Gender              50
# SeniorCitizen       50
# Partner             50
# Dependents          50
# Tenure              50
# PhoneService        50
# MultipleLines       50
# InternetService     50
# OnlineSecurity      50
# OnlineBackup        50
# DeviceProtection    50
# TechSupport         50
# StreamingTV         50
# StreamingMovies     50
# Contract            50
# PaperlessBilling    50
# PaymentMethod       50
# MonthlyCharges      50
# TotalCharges        50
# Churn               50
# dtype: int64

# %%
#Standard Deviation - column wise
calliDf.std()
# Out:
# MedInc           1.899822
# HouseAge        12.585558
# AveRooms         2.474173
# AveBedrms        0.473911
# Population    1132.462122
# AveOccup        10.386050
# Latitude         2.135952
# Longitude        2.003532
# dtype: float64

# %%
#Max value - column wise
calliDf.max()
# Out:
# MedInc           15.000100
# HouseAge         52.000000
# AveRooms        141.909091
# AveBedrms        34.066667
# Population    35682.000000
# AveOccup       1243.333333
# Latitude         41.950000
# Longitude      -114.310000
# dtype: float64

# %%
#Min value - column wise
calliDf.min()
# Out:
# MedInc          0.499900
# HouseAge        1.000000
# AveRooms        0.846154
# AveBedrms       0.333333
# Population      3.000000
# AveOccup        0.692308
# Latitude       32.540000
# Longitude    -124.350000
# dtype: float64

# %%
#Manipulating DataFrame

#Adding a new column

#adding target values in calliDf
price = housing.target
print(price)

calliDf['Price'] = price
calliDf.head()
# Out:
# [4.526 3.585 3.521 ... 0.923 0.847 0.894]
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  Price
# 0    -122.23  4.526
# 1    -122.22  3.585
# 2    -122.24  3.521
# 3    -122.25  3.413
# 4    -122.25  3.422

# %%
#remove a row
calliDf.drop(index=0 , axis= 0 ) #remove first row #for row axis =0 for coulmn axis =1
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# 5      4.0368      52.0  4.761658   1.103627       413.0  2.139896     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  Price
# ...

# %%
#remove a column
calliDf.drop(columns='Population' , axis=1) #remove Price column
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  AveOccup  Latitude  Longitude  \
# 0      8.3252      41.0  6.984127   1.023810  2.555556     37.88    -122.23
# 1      8.3014      21.0  6.238137   0.971880  2.109842     37.86    -122.22
# 2      7.2574      52.0  8.288136   1.073446  2.802260     37.85    -122.24
# 3      5.6431      52.0  5.817352   1.073059  2.547945     37.85    -122.25
# 4      3.8462      52.0  6.281853   1.081081  2.181467     37.85    -122.25
# ...       ...       ...       ...        ...       ...       ...        ...
# 20635  1.5603      25.0  5.045455   1.133333  2.560606     39.48    -121.09
# 20636  2.5568      18.0  6.114035   1.315789  3.122807     39.49    -121.21
# 20637  1.7000      17.0  5.205543   1.120092  2.325635     39.43    -121.22
# 20638  1.8672      18.0  5.329513   1.171920  2.123209     39.43    -121.32
# 20639  2.3886      16.0  5.254717   1.162264  2.616981     39.37    -121.24
#
#        Price
# 0      4.526
# 1      3.585
# ...

# %%
#locate/print particular row
customers.iloc[3]
# Out:
# CustomerID                CUST0004
# Gender                      Female
# SeniorCitizen                    1
# Partner                         No
# Dependents                     Yes
# Tenure                           4
# PhoneService                    No
# MultipleLines                  Yes
# InternetService                DSL
# OnlineSecurity                 Yes
# OnlineBackup                    No
# DeviceProtection               Yes
# TechSupport                     No
# StreamingTV                    Yes
# StreamingMovies                 No
# Contract            Month-to-month
# PaperlessBilling                No
# PaymentMethod          Credit card
# MonthlyCharges                26.0
# TotalCharges                 104.0
# Churn                          Yes
# Name: 3, dtype: object

# %%
#locate particular column
customers['Churn']
# Out:
# 0      No
# 1      No
# 2      No
# 3     Yes
# 4      No
# 5      No
# 6      No
# 7     Yes
# 8      No
# 9      No
# 10     No
# 11    Yes
# 12     No
# 13     No
# 14     No
# 15    Yes
# 16     No
# 17     No
# 18     No
# 19    Yes
# 20     No
# 21     No
# 22     No
# 23    Yes
# 24     No
# 25     No
# 26     No
# 27    Yes
# 28     No
# 29     No
# 30     No
# 31    Yes
# 32     No
# 33     No
# 34     No
# 35    Yes
# 36     No
# 37     No
# 38     No
# 39    Yes
# 40     No
# 41     No
# 42     No
# 43    Yes
# 44     No
# 45     No
# 46     No
# 47    Yes
# 48     No
# 49     No
# Name: Churn, dtype: object

# %%
#Another way to locate particular column
print(customers.iloc[:,1]) #prints second column
print(customers.iloc[:,-1]) #prints last column
# Out:
# 0       Male
# 1     Female
# 2       Male
# 3     Female
# 4       Male
# 5     Female
# 6       Male
# 7     Female
# 8       Male
# 9     Female
# 10      Male
# 11    Female
# 12      Male
# 13    Female
# 14      Male
# 15    Female
# 16      Male
# 17    Female
# 18      Male
# 19    Female
# 20      Male
# 21    Female
# 22      Male
# 23    Female
# 24      Male
# 25    Female
# 26      Male
# 27    Female
# 28      Male
# 29    Female
# 30      Male
# 31    Female
# 32      Male
# 33    Female
# 34      Male
# 35    Female
# 36      Male
# 37    Female
# 38      Male
# 39    Female
# 40      Male
# 41    Female
# 42      Male
# 43    Female
# 44      Male
# 45    Female
# 46      Male
# 47    Female
# 48      Male
# 49    Female
# Name: Gender, dtype: object
# 0      No
# 1      No
# 2      No
# 3     Yes
# 4      No
# 5      No
# 6      No
# 7     Yes
# 8      No
# 9      No
# 10     No
# 11    Yes
# 12     No
# 13     No
# 14     No
# 15    Yes
# 16     No
# 17     No
# ...

# %%
#Correlation - used to find relation between two variables/columns
#Positive Correlation - one value inc if other inc
#Negative Correlation - one value inc if other dec

# %%
calliDf.corr()
# Out:
#               MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# MedInc      1.000000 -0.119034  0.326895  -0.062040    0.004834  0.018766
# HouseAge   -0.119034  1.000000 -0.153277  -0.077747   -0.296244  0.013191
# AveRooms    0.326895 -0.153277  1.000000   0.847621   -0.072213 -0.004852
# AveBedrms  -0.062040 -0.077747  0.847621   1.000000   -0.066197 -0.006181
# Population  0.004834 -0.296244 -0.072213  -0.066197    1.000000  0.069863
# AveOccup    0.018766  0.013191 -0.004852  -0.006181    0.069863  1.000000
# Latitude   -0.079809  0.011173  0.106389   0.069721   -0.108785  0.002366
# Longitude  -0.015176 -0.108197 -0.027540   0.013344    0.099773  0.002476
# Price       0.688075  0.105623  0.151948  -0.046701   -0.024650 -0.023737
#
#             Latitude  Longitude     Price
# MedInc     -0.079809  -0.015176  0.688075
# HouseAge    0.011173  -0.108197  0.105623
# AveRooms    0.106389  -0.027540  0.151948
# AveBedrms   0.069721   0.013344 -0.046701
# ...
