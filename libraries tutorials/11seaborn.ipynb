# %%
#Seaborn Library
#Seaborn is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics.

# %%
#import seaborn libraries
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# Seaborn has some built in data dataset

# %%
#total bill vs tip dataset
tips = sns.load_dataset('tips')
print(tips.head())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#Setting a theme
sns.set_theme()

# %%
#Visualize tips dataset
sns.relplot(data=tips, x='total_bill',y='tip',col='time',hue='smoker',style='smoker',size='size')

# %%
#Visualize customers dataset

customers = pd.read_csv('../dataset/customers.csv')
#customers.head()

#I want to see the relationship between the total bill & churn and see if monthly subscription has any effect on it with size of tenure
sns.relplot(data=customers, x='MonthlyCharges', y='Churn', hue='Contract', style='Contract', size='Tenure')
sns.relplot(data=customers, x='TotalCharges', y='Churn', hue='Contract', style='Contract', size='Tenure')

#I don't see any clear relation bw churn and charges. Let's try with services
#Phone Services Customer
sns.relplot(data=customers, x='PhoneService', y='Churn') #people who have phone service are not leaving #people who do not have phone service are leaving/statying

#InternetService
sns.relplot(data=customers, x='InternetService', y='Churn') #Nothing conclusive

#OnlineSecurity
sns.relplot(data=customers, x='OnlineSecurity', y='Churn') #people who have online security are not leaving #people who do not have phone service are leaving/statying

#OnlineBackup
sns.relplot(data=customers, x='OnlineBackup', y='Churn') #people who have online security are not leaving #people who do not have phone service are leaving/statying

#DeviceProtection
sns.relplot(data=customers, x='DeviceProtection', y='Churn') #people who have online security are not leaving #people who do not have phone service are leaving/statying

#TechSupport
sns.relplot(data=customers, x='TechSupport', y='Churn') #people who have online security are not leaving #people who do not have phone service are leaving/statying

#StreamingTV
sns.relplot(data=customers, x='StreamingTV', y='Churn') #people who have online security are not leaving #people who do not have phone service are leaving/statying

#StreamingMovies
sns.relplot(data=customers, x='StreamingMovies', y='Churn') #people who have online security are not leaving #people who do not have phone service are leaving/statying

#Contract
sns.relplot(data=customers, x='Contract', y='Churn') #Nothing conclusive

#PaperlessBilling
sns.relplot(data=customers, x='PaperlessBilling', y='Churn') #people who have online security are not leaving #people who do not have phone service are leaving/statying

#PaymentMethod
sns.relplot(data=customers, x='PaymentMethod', y='Churn') #people with credit card are leaving

#MonthlyCharges
sns.relplot(data=customers, x='MonthlyCharges', y='Churn',size='MonthlyCharges') #Nothing conclusive

#TotalCharges
sns.relplot(data=customers, x='TotalCharges', y='Churn',size='TotalCharges')#Nothing conclusive

#Tenure
sns.relplot(data=customers, x='Tenure', y='Churn',size='Tenure') #Nothing conclusive

#I see several columns where if a person has that facility they are not leaving. Should we then not consider that column when training our model?
#According to above assumption the column that we should keep are - InternetService,Contract,MonthlyCharges,TotalCharges,Tenure
#Ask about PaymentMethod- Credit Card

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.scatterplot(data=iris, x='sepal_length', y='petal_length', hue='species')


#Another way
#sns.relplot(data=iris, x='sepal_length', y='petal_length', hue='species')
#sns.relplot(data=iris, x='sepal_width', y='petal_width', hue='species')
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
sns.scatterplot(data=iris, x='sepal_width', y='petal_width', hue='species')
# Out:
# <Axes: xlabel='sepal_width', ylabel='petal_width'>

# %%
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
#count plot
sns.countplot(data=titanic, x='class', hue='who')
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
sns.countplot(data=titanic, x='survived')
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
#Bar Chart
sns.barplot(data=titanic, x='sex', y='survived', hue='class')
# Out:
# <Axes: xlabel='sex', ylabel='survived'>

# %%
#house price dataset
from sklearn.datasets import fetch_california_housing
houseing = fetch_california_housing()
house_price = pd.DataFrame(houseing.data, columns=houseing.feature_names)
house_price['Price'] = houseing.target
house_price.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  Price
# 0    -122.23  4.526
# 1    -122.22  3.585
# 2    -122.24  3.521
# 3    -122.25  3.413
# 4    -122.25  3.422

# %%
#Distribution plot
sns.displot(house_price['Price'])

# %%
sns.distplot(house_price['Price'])
# Out:
# /var/folders/fp/f4bk79gx49jfznzyf5zn4vlw0000gq/T/ipykernel_58358/2406769558.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(house_price['Price'])
# <Axes: xlabel='Price', ylabel='Density'>

# %%
sns.histplot(house_price['Price'])
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %%
#Correlation
correlation = house_price.corr()

# %%
#Plot correlation values
plt.figure(figsize=(10,10))
sns.heatmap(correlation, cbar=True, square=True, fmt='.3f', annot=True, annot_kws={'size':8}, cmap='Blues')
#columns in x-axis and y-axis are same because we are comparing the same columns
#cbar - colur bar
#square - square shape
#fmt - format of the values
#annot - annotation
#annot_kws - annotation keyword size , font size
#cmap - color map
# Out:
# <Axes: >

# %%
#Pairplot
sns.pairplot(house_price)
